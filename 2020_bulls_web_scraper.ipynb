# %% [markdown]
# ## Project Purpose:
# ### In this personal project, I will create a machine learning model that will accurately predict whether the Chicago Bulls basketball team will win a given game based on that games statistics (box score). To do this, I need a dataset containing the team's stat totals for all 72 regular season basketball games in the 2020-2021 season.
# ### After some searching, I was unable to find such a dataset. However, I was able to locate a website that contained links to all 72 box scores. From these box score pages, I will scrape the desired data. When this is complete, I will clean and model the data to fit my requirements for this project. Next, I'll use this cleaned dataset to train and test my Random Forest model.

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)

# %%
url = "https://www.basketball-reference.com/teams/CHI/2021_games.html"

# %%
r = requests.get(url)

# %%
r.status_code #check to see if site allows web scraping (if 200 prints, we're good to go.)
# Out:
# 200

# %%
data = r.text

# %%
soup = BeautifulSoup(data,'html.parser')

# %%
#pull all links for HTML page
my_list = []
for link in soup.find_all('a'): #Find all link tags
    my_list.append(link.get('href')) #append links

# %%
my_list
# Out:
# ['https://www.sports-reference.com/',
#  'https://www.baseball-reference.com/',
#  'https://www.pro-football-reference.com/',
#  'https://www.sports-reference.com/cfb/',
#  'https://www.basketball-reference.com/',
#  'https://www.sports-reference.com/cbb/',
#  'https://www.hockey-reference.com/',
#  'https://fbref.com/es/',
#  'https://www.sports-reference.com/blog/',
#  'https://stathead.com/?utm_source=web&utm_medium=bbr&utm_campaign=sr-nav-bar-top-link',
#  'https://widgets.sports-reference.com/',
#  '#',
#  'https://stathead.com/profile/?utm_source=web&utm_medium=bbr&utm_campaign=sr-nav-bar-top-account',
#  'https://stathead.com/profile/?do=logout',
#  'https://stathead.com/users/login.cgi?token=1',
#  'https://stathead.com/users/signup.cgi',
#  '/',
#  '#site_menu_link',
#  '/players/',
#  '/teams/',
#  '/leagues/',
#  '/leaders/',
#  '/boxscores/',
#  '/wnba/',
#  '/draft/',
#  'https://stathead.com/basketball/',
#  'https://stathead.com/newsletter.cgi?site_sub=bbr',
#  '#site_menu_link',
#  '/',
#  '/teams/',
#  '/teams/CHI/',
#  'https://stathead.com/profile/?utm_source=web&utm_medium=bbr&utm_campaign=sr-nav-bar-top-account',
#  'https://stathead.com/profile/?do=logout',
#  'https://stathead.com/users/login.cgi?token=1',
#  'https://stathead.com/users/signup.cgi',
#  'http://www.sportslogos.net/',
#  'https://www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/',
#  '/teams/CHI/2020_games.html',
#  '/teams/CHI/2022_games.html',
#  '/leagues/NBA_2021.html',
#  '/boxscores/202105160CHI.html',
#  '/coaches/donovbi99c.html',
#  '/executives/karniar99x.html',
#  '/about/glossary.html#srs',
#  '/about/glossary.html#pace',
#  '/about/glossary.html#off_rtg',
#  '/about/glossary.html#def_rtg',
#  '/about/glossary.html#wins_pyth',
#  '/leagues/NBA_2021_preseason_odds.html',
#  '/leagues/NBA_2021_preseason_odds.html',
#  '/teams/CHI/',
#  '/teams/CHI/2021.html',
#  '/teams/CHI/2021_games.html',
#  '/teams/CHI/2021_transactions.html',
#  '/teams/CHI/2021/gamelog/',
#  '/teams/CHI/2021/splits/',
#  '/teams/CHI/2021/lineups/',
#  '/teams/CHI/2021/on-off/',
#  '/teams/CHI/2021_start.html',
#  '/teams/CHI/2021_depth.html',
#  '/teams/CHI/2021_referees.html',
#  '/teams/CHI/2021.html',
#  '/teams/CHI/2021_games.html',
#  '/teams/CHI/2021_transactions.html',
#  '/teams/CHI/2021/gamelog/',
#  '/teams/CHI/2021/splits/',
#  '/teams/CHI/2021/lineups/',
#  '/teams/CHI/2021/on-off/',
#  '/teams/CHI/2021_start.html',
#  '/teams/CHI/2021_depth.html',
#  '/teams/CHI/2021_referees.html',
#  '/boxscores/index.cgi?month=12&day=23&year=2020',
#  '/boxscores/202012230CHI.html',
#  '/teams/ATL/2021.html',
#  '/boxscores/index.cgi?month=12&day=26&year=2020',
#  '/boxscores/202012260CHI.html',
#  '/teams/IND/2021.html',
#  '/boxscores/index.cgi?month=12&day=27&year=2020',
#  '/boxscores/202012270CHI.html',
#  '/teams/GSW/2021.html',
#  '/boxscores/index.cgi?month=12&day=29&year=2020',
#  '/boxscores/202012290WAS.html',
#  '/teams/WAS/2021.html',
#  '/boxscores/index.cgi?month=12&day=31&year=2020',
#  '/boxscores/202012310WAS.html',
#  '/teams/WAS/2021.html',
#  '/boxscores/index.cgi?month=1&day=1&year=2021',
#  '/boxscores/202101010MIL.html',
#  '/teams/MIL/2021.html',
#  '/boxscores/index.cgi?month=1&day=3&year=2021',
#  '/boxscores/202101030CHI.html',
#  '/teams/DAL/2021.html',
#  '/boxscores/index.cgi?month=1&day=5&year=2021',
#  '/boxscores/202101050POR.html',
#  '/teams/POR/2021.html',
#  '/boxscores/index.cgi?month=1&day=6&year=2021',
#  '/boxscores/202101060SAC.html',
#  '/teams/SAC/2021.html',
#  '/boxscores/index.cgi?month=1&day=8&year=2021',
#  '/boxscores/202101080LAL.html',
#  '/teams/LAL/2021.html',
#  '/boxscores/index.cgi?month=1&day=10&year=2021',
#  '/boxscores/202101100LAC.html',
#  '/teams/LAC/2021.html',
#  '/boxscores/index.cgi?month=1&day=15&year=2021',
#  '/boxscores/202101150OKC.html',
#  '/teams/OKC/2021.html',
#  '/boxscores/index.cgi?month=1&day=17&year=2021',
#  '/boxscores/202101170DAL.html',
#  '/teams/DAL/2021.html',
#  '/boxscores/index.cgi?month=1&day=18&year=2021',
#  '/boxscores/202101180CHI.html',
#  '/teams/HOU/2021.html',
#  '/boxscores/index.cgi?month=1&day=22&year=2021',
#  '/boxscores/202101220CHO.html',
#  '/teams/CHO/2021.html',
#  '/boxscores/index.cgi?month=1&day=23&year=2021',
#  '/boxscores/202101230CHI.html',
#  '/teams/LAL/2021.html',
#  '/boxscores/index.cgi?month=1&day=25&year=2021',
#  '/boxscores/202101250CHI.html',
#  '/teams/BOS/2021.html',
#  '/boxscores/index.cgi?month=1&day=30&year=2021',
#  '/boxscores/202101300CHI.html',
#  '/teams/POR/2021.html',
#  '/boxscores/index.cgi?month=2&day=1&year=2021',
#  '/boxscores/202102010CHI.html',
#  '/teams/NYK/2021.html',
#  '/boxscores/index.cgi?month=2&day=3&year=2021',
#  '/boxscores/202102030CHI.html',
#  '/teams/NYK/2021.html',
#  '/boxscores/index.cgi?month=2&day=5&year=2021',
#  '/boxscores/202102050ORL.html',
#  '/teams/ORL/2021.html',
#  '/boxscores/index.cgi?month=2&day=6&year=2021',
#  '/boxscores/202102060ORL.html',
#  '/teams/ORL/2021.html',
#  '/boxscores/index.cgi?month=2&day=8&year=2021',
#  '/boxscores/202102080CHI.html',
#  '/teams/WAS/2021.html',
#  '/boxscores/index.cgi?month=2&day=10&year=2021',
#  '/boxscores/202102100CHI.html',
#  '/teams/NOP/2021.html',
#  '/boxscores/index.cgi?month=2&day=12&year=2021',
#  '/boxscores/202102120CHI.html',
#  '/teams/LAC/2021.html',
#  '/boxscores/index.cgi?month=2&day=15&year=2021',
#  '/boxscores/202102150IND.html',
#  '/teams/IND/2021.html',
#  '/boxscores/index.cgi?month=2&day=17&year=2021',
#  '/boxscores/202102170CHI.html',
#  '/teams/DET/2021.html',
#  '/boxscores/index.cgi?month=2&day=19&year=2021',
#  '/boxscores/202102190PHI.html',
#  '/teams/PHI/2021.html',
#  '/boxscores/index.cgi?month=2&day=20&year=2021',
#  '/boxscores/202102200CHI.html',
#  '/teams/SAC/2021.html',
#  '/boxscores/index.cgi?month=2&day=22&year=2021',
#  '/boxscores/202102220HOU.html',
#  '/teams/HOU/2021.html',
#  '/boxscores/index.cgi?month=2&day=24&year=2021',
#  '/boxscores/202102240CHI.html',
#  '/teams/MIN/2021.html',
#  '/boxscores/index.cgi?month=2&day=26&year=2021',
#  '/boxscores/202102260CHI.html',
#  '/teams/PHO/2021.html',
#  '/boxscores/index.cgi?month=3&day=1&year=2021',
#  '/boxscores/202103010CHI.html',
#  '/teams/DEN/2021.html',
#  '/boxscores/index.cgi?month=3&day=3&year=2021',
#  '/boxscores/202103030NOP.html',
#  '/teams/NOP/2021.html',
#  '/boxscores/index.cgi?month=3&day=11&year=2021',
#  '/boxscores/202103110CHI.html',
#  '/teams/PHI/2021.html',
#  '/boxscores/index.cgi?month=3&day=12&year=2021',
#  '/boxscores/202103120CHI.html',
#  '/teams/MIA/2021.html',
#  '/boxscores/index.cgi?month=3&day=14&year=2021',
#  '/boxscores/202103140CHI.html',
#  '/teams/TOR/2021.html',
#  '/boxscores/index.cgi?month=3&day=16&year=2021',
#  '/boxscores/202103160CHI.html',
#  '/teams/OKC/2021.html',
#  '/boxscores/index.cgi?month=3&day=17&year=2021',
#  '/boxscores/202103170CHI.html',
#  '/teams/SAS/2021.html',
#  '/boxscores/index.cgi?month=3&day=19&year=2021',
#  '/boxscores/202103190DEN.html',
#  '/teams/DEN/2021.html',
#  '/boxscores/index.cgi?month=3&day=21&year=2021',
#  '/boxscores/202103210DET.html',
#  '/teams/DET/2021.html',
#  '/boxscores/index.cgi?month=3&day=22&year=2021',
#  '/boxscores/202103220CHI.html',
#  '/teams/UTA/2021.html',
#  '/boxscores/index.cgi?month=3&day=24&year=2021',
#  '/boxscores/202103240CHI.html',
#  '/teams/CLE/2021.html',
#  '/boxscores/index.cgi?month=3&day=27&year=2021',
#  '/boxscores/202103270SAS.html',
#  '/teams/SAS/2021.html',
#  '/boxscores/index.cgi?month=3&day=29&year=2021',
#  '/boxscores/202103290GSW.html',
#  '/teams/GSW/2021.html',
#  '/boxscores/index.cgi?month=3&day=31&year=2021',
#  '/boxscores/202103310PHO.html',
#  '/teams/PHO/2021.html',
#  '/boxscores/index.cgi?month=4&day=2&year=2021',
#  '/boxscores/202104020UTA.html',
#  '/teams/UTA/2021.html',
#  '/boxscores/index.cgi?month=4&day=4&year=2021',
#  '/boxscores/202104040CHI.html',
#  '/teams/BRK/2021.html',
#  '/boxscores/index.cgi?month=4&day=6&year=2021',
#  '/boxscores/202104060IND.html',
#  '/teams/IND/2021.html',
#  '/boxscores/index.cgi?month=4&day=8&year=2021',
#  '/boxscores/202104080TOR.html',
#  '/teams/TOR/2021.html',
#  '/boxscores/index.cgi?month=4&day=9&year=2021',
#  '/boxscores/202104090ATL.html',
#  '/teams/ATL/2021.html',
#  '/boxscores/index.cgi?month=4&day=11&year=2021',
#  '/boxscores/202104110MIN.html',
#  '/teams/MIN/2021.html',
#  '/boxscores/index.cgi?month=4&day=12&year=2021',
#  '/boxscores/202104120MEM.html',
#  '/teams/MEM/2021.html',
#  '/boxscores/index.cgi?month=4&day=14&year=2021',
#  '/boxscores/202104140CHI.html',
#  '/teams/ORL/2021.html',
#  '/boxscores/index.cgi?month=4&day=16&year=2021',
#  '/boxscores/202104160CHI.html',
#  '/teams/MEM/2021.html',
#  '/boxscores/index.cgi?month=4&day=17&year=2021',
#  '/boxscores/202104170CHI.html',
#  '/teams/CLE/2021.html',
#  '/boxscores/index.cgi?month=4&day=19&year=2021',
#  '/boxscores/202104190BOS.html',
#  '/teams/BOS/2021.html',
#  '/boxscores/index.cgi?month=4&day=21&year=2021',
#  '/boxscores/202104210CLE.html',
#  '/teams/CLE/2021.html',
#  '/boxscores/index.cgi?month=4&day=22&year=2021',
#  '/boxscores/202104220CHI.html',
#  '/teams/CHO/2021.html',
#  '/boxscores/index.cgi?month=4&day=24&year=2021',
#  '/boxscores/202104240MIA.html',
#  '/teams/MIA/2021.html',
#  '/boxscores/index.cgi?month=4&day=26&year=2021',
#  '/boxscores/202104260MIA.html',
#  '/teams/MIA/2021.html',
#  '/boxscores/index.cgi?month=4&day=28&year=2021',
#  '/boxscores/202104280NYK.html',
#  '/teams/NYK/2021.html',
#  '/boxscores/index.cgi?month=4&day=30&year=2021',
#  '/boxscores/202104300CHI.html',
#  '/teams/MIL/2021.html',
#  '/boxscores/index.cgi?month=5&day=1&year=2021',
#  '/boxscores/202105010ATL.html',
#  '/teams/ATL/2021.html',
#  '/boxscores/index.cgi?month=5&day=3&year=2021',
#  '/boxscores/202105030CHI.html',
#  '/teams/PHI/2021.html',
#  '/boxscores/index.cgi?month=5&day=6&year=2021',
#  '/boxscores/202105060CHO.html',
#  '/teams/CHO/2021.html',
#  '/boxscores/index.cgi?month=5&day=7&year=2021',
#  '/boxscores/202105070CHI.html',
#  '/teams/BOS/2021.html',
#  '/boxscores/index.cgi?month=5&day=9&year=2021',
#  '/boxscores/202105090DET.html',
#  '/teams/DET/2021.html',
#  '/boxscores/index.cgi?month=5&day=11&year=2021',
#  '/boxscores/202105110CHI.html',
#  '/teams/BRK/2021.html',
#  '/boxscores/index.cgi?month=5&day=13&year=2021',
#  '/boxscores/202105130CHI.html',
#  '/teams/TOR/2021.html',
#  '/boxscores/index.cgi?month=5&day=15&year=2021',
#  '/boxscores/202105150BRK.html',
#  '/teams/BRK/2021.html',
#  '/boxscores/index.cgi?month=5&day=16&year=2021',
#  '/boxscores/202105160CHI.html',
#  '/teams/MIL/2021.html',
#  '/teams/CHI/',
#  '/teams/CHI/2021.html',
#  '/teams/CHI/2021_games.html',
#  '/teams/CHI/2021_transactions.html',
#  '/teams/CHI/2021/gamelog/',
#  '/teams/CHI/2021/splits/',
#  '/teams/CHI/2021/lineups/',
#  '/teams/CHI/2021/on-off/',
#  '/teams/CHI/2021_start.html',
#  '/teams/CHI/2021_depth.html',
#  '/teams/CHI/2021_referees.html',
#  'https://stathead.com/profile/?utm_source=web&utm_medium=bbr&utm_campaign=sr-nav-bar-top-account',
#  'https://stathead.com/profile/?do=logout',
#  'https://stathead.com/users/login.cgi?token=1',
#  'https://stathead.com/users/signup.cgi',
#  '/',
#  '/teams/',
#  '/teams/CHI/',
#  '#header',
#  '/players/',
#  '/players/j/jamesle01.html',
#  '/players/d/duranke01.html',
#  '/players/e/embiijo01.html',
#  '/players/h/hardeja01.html',
#  '/players/c/curryst01.html',
#  '/players/d/doncilu01.html',
#  '/players/',
#  '/players/h/hayesel01.html',
#  '/players/s/stockjo01.html',
#  '/players/o/olajuha01.html',
#  '/players/c/chambwi01.html',
#  '/players/s/schaydo01.html',
#  '/players/h/havlijo01.html',
#  '/players/',
#  '/players/j/jamesle01.html',
#  '/players/j/jamesle01.html',
#  '/players/p/paulch01.html',
#  '/players/h/hardeja01.html',
#  '/players/c/curryst01.html',
#  '/players/d/duranke01.html',
#  '/players/',
#  '/teams/',
#  '/teams/TOR/2021.html',
#  '/teams/BOS/2021.html',
#  '/teams/NYK/2021.html',
#  '/teams/BRK/2021.html',
#  '/teams/PHI/2021.html',
#  '/teams/CLE/2021.html',
#  '/teams/IND/2021.html',
#  '/teams/DET/2021.html',
#  '/teams/CHI/2021.html',
#  '/teams/MIL/2021.html',
#  '/teams/MIA/2021.html',
#  '/teams/ATL/2021.html',
#  '/teams/CHO/2021.html',
#  '/teams/WAS/2021.html',
#  '/teams/ORL/2021.html',
#  '/teams/OKC/2021.html',
#  '/teams/POR/2021.html',
#  '/teams/UTA/2021.html',
#  '/teams/DEN/2021.html',
#  '/teams/MIN/2021.html',
#  '/teams/GSW/2021.html',
#  '/teams/LAC/2021.html',
#  '/teams/SAC/2021.html',
#  '/teams/PHO/2021.html',
#  '/teams/LAL/2021.html',
#  '/teams/SAS/2021.html',
#  '/teams/DAL/2021.html',
#  '/teams/MEM/2021.html',
#  '/teams/HOU/2021.html',
#  '/teams/NOP/2021.html',
#  '/leagues/',
#  '/leagues/NBA_2021.html',
#  '/leagues/NBA_2020.html',
#  '/leagues/NBA_2019.html',
#  '/leagues/NBA_2018.html',
#  '/leagues/NBA_2017.html',
#  '/leagues/NBA_2016.html',
#  '/leaders/',
#  '/leaders/pts_season.html',
#  '/leaders/trb_career.html',
#  '/leaders/ast_active.html',
#  '/leaders/stl_yearly.html',
#  '/leaders/blk_progress.html',
#  '/trailers/',
#  '/trailers/fg_pct_season.html',
#  '/trailers/blk_per_g_career.html',
#  '/boxscores/',
#  '/boxscores/',
#  '/boxscores/',
#  '/leagues/NBA_2021_games.html',
#  '/teams/MIL/2021_games.html',
#  '/leagues/NBA_2021_games.html',
#  '/leagues/NBA_2021_standings.html',
#  '/leagues/NBA_2021_standings.html',
#  '/friv/standings.fcgi',
#  'https://stathead.com/basketball/',
#  'https://stathead.com/basketball/psl_finder.cgi',
#  'https://stathead.com/basketball/pgl_finder.cgi',
#  'https://stathead.com/basketball/pstreak.cgi',
#  'https://stathead.com/basketball/pspan_finder.cgi',
#  'https://stathead.com/basketball/tsl_finder.cgi',
#  'https://stathead.com/basketball/tgl_finder.cgi',
#  'https://stathead.com/basketball/tstreak.cgi',
#  'https://stathead.com/basketball/tscore.cgi',
#  'https://stathead.com/basketball/rivals.cgi',
#  'https://stathead.com/basketball/wnba_psl_finder.cgi',
#  'https://stathead.com/basketball/wnba_pgl_finder.cgi',
#  'https://stathead.com/basketball/wnba_pcm_finder.cgi',
#  'https://stathead.com/basketball/draft_finder.cgi',
#  'https://stathead.com/basketball/h2h_finder.cgi',
#  'https://stathead.com/basketball/pcm_finder.cgi',
#  '/coaches/',
#  '/coaches/gueriri01c.html',
#  '/coaches/tomjaru01c.html',
#  '/coaches/obrieji99c.html',
#  '/coaches/fratemi99c.html',
#  '/coaches/gentral99c.html',
#  '/awards/',
#  '/awards/mvp.html',
#  '/awards/all_league.html',
#  '/awards/dpoy.html',
#  '/awards/roy.html',
#  '/awards/all_rookie.html',
#  '/awards/hof.html',
#  '/contracts/',
#  '/contracts/',
#  '/contracts/ATL.html',
#  '/contracts/players.html',
#  '/contracts/glossary.html',
#  '/playoffs/',
#  '/playoffs/NBA_2020.html',
#  '/playoffs/NBA_2019.html',
#  '/playoffs/NBA_2018.html',
#  '/playoffs/NBA_2017.html',
#  '/playoffs/',
#  '/allstar/',
#  '/allstar/NBA_2021.html',
#  '/allstar/NBA_2020.html',
#  '/allstar/NBA_2019.html',
#  '/allstar/NBA_2018.html',
#  '/draft/',
#  '/draft/NBA_2020.html',
#  '/draft/NBA_2019.html',
#  '/draft/NBA_2018.html',
#  '/draft/NBA_2017.html',
#  '/draft/NBA_2016.html',
#  '/friv/',
#  '/friv/birthdays.fcgi',
#  '/friv/colleges.fcgi',
#  '/friv/high_schools.fcgi',
#  '/friv/milestones.fcgi',
#  '/executives/',
#  '/executives/buforrc99x.html',
#  '/executives/embrywa01x.html',
#  '/executives/kastest99x.html',
#  '/executives/aingeda01x.html',
#  '/executives/nelsodo01x.html',
#  '/referees/',
#  '/referees/fortejo99r.html',
#  '/referees/brothto99r.html',
#  '/referees/crawfda99r.html',
#  '/referees/olesiro99r.html',
#  '/referees/jonesda99r.html',
#  '/gleague/',
#  '/gleague/players/',
#  '/gleague/teams/',
#  '/gleague/years/',
#  '/gleague/leaders/',
#  '/gleague/awards/',
#  '/international/',
#  '/international/players/',
#  '/international/teams/',
#  '/international/years/',
#  '/international/leaders/',
#  '/international/awards/',
#  '/wnba/',
#  '/wnba/players/',
#  '/wnba/teams/',
#  '/wnba/years/',
#  '/wnba/leaders/',
#  '/wnba/awards/',
#  '/wnba/allstar/',
#  '/nbl/',
#  '/nbl/players/',
#  '/nbl/teams/',
#  '/nbl/years/',
#  '/nbl/leaders/',
#  '/nbl/awards/',
#  '/about/',
#  '/about/glossary.html',
#  '/about/contact.html',
#  'tel://888-512-8907',
#  '//www.sports-reference.com/blog/',
#  'https://www.sports-reference.com/blog/feed/',
#  'https://www.facebook.com/Basketball.Reference',
#  'https://twitter.com/bball_ref',
#  'https://instagram.com/basketball.reference',
#  'https://reddit.com/r/SportsReference',
#  'https://www.youtube.com/user/sportsreference',
#  'https://www.linkedin.com/company/sports-reference-llc',
#  'https://www.paypal.me/sportsref',
#  'https://www.sports-reference.com/blog/sports-reference-social-media/',
#  '#',
#  'https://stathead.com/?&utm_medium=sr&utm_source=bbr&utm_campaign=site-footer',
#  'https://www.sports-reference.com/this-month.html?&utm_medium=sr&utm_source=bbr&utm_campaign=site-footer-twisr',
#  'https://www.sports-reference.com/blog/ways-sports-reference-can-help-your-website/?utm_medium=sr&utm_source=bbr&utm_campaign=site-footer-ways-help',
#  '//www.sports-reference.com/blog/category/tips-and-tricks/',
#  '/linker/',
#  'https://www.sports-reference.com/blog/category/stathead-tutorial-series/',
#  '//stathead.com/',
#  'https://www.sports-reference.com/blog/2016/06/redesign-team-and-league-logos-courtesy-sportslogos-net/',
#  'http://sportslogos.net/',
#  'https://www.sportradar.com/',
#  '//www.sports-reference.com/',
#  'https://www.sports-reference.com/',
#  'https://www.baseball-reference.com/',
#  'https://www.pro-football-reference.com/',
#  'https://www.sports-reference.com/cfb/',
#  'https://www.basketball-reference.com/',
#  'https://www.sports-reference.com/cbb/',
#  'https://www.hockey-reference.com/',
#  'https://fbref.com/es/',
#  'https://www.sports-reference.com/blog/',
#  'https://stathead.com/?utm_source=web&utm_medium=bbr&utm_campaign=sr-nav-bar-top-link',
#  'https://widgets.sports-reference.com/',
#  '//www.sports-reference.com/about.html',
#  '//www.sports-reference.com/privacy.html',
#  '//www.sports-reference.com/termsofuse.html',
#  '//www.sports-reference.com/advertise.html',
#  '//www.sports-reference.com/data_use.html']

# %%
#Collect all the boxscore links
box_scores = []
for i in my_list:
    if "boxscores/2" in i:
        box_scores.append(i)

# %%
box_scores #shows path to box scores
# Out:
# ['/boxscores/202105160CHI.html',
#  '/boxscores/202012230CHI.html',
#  '/boxscores/202012260CHI.html',
#  '/boxscores/202012270CHI.html',
#  '/boxscores/202012290WAS.html',
#  '/boxscores/202012310WAS.html',
#  '/boxscores/202101010MIL.html',
#  '/boxscores/202101030CHI.html',
#  '/boxscores/202101050POR.html',
#  '/boxscores/202101060SAC.html',
#  '/boxscores/202101080LAL.html',
#  '/boxscores/202101100LAC.html',
#  '/boxscores/202101150OKC.html',
#  '/boxscores/202101170DAL.html',
#  '/boxscores/202101180CHI.html',
#  '/boxscores/202101220CHO.html',
#  '/boxscores/202101230CHI.html',
#  '/boxscores/202101250CHI.html',
#  '/boxscores/202101300CHI.html',
#  '/boxscores/202102010CHI.html',
#  '/boxscores/202102030CHI.html',
#  '/boxscores/202102050ORL.html',
#  '/boxscores/202102060ORL.html',
#  '/boxscores/202102080CHI.html',
#  '/boxscores/202102100CHI.html',
#  '/boxscores/202102120CHI.html',
#  '/boxscores/202102150IND.html',
#  '/boxscores/202102170CHI.html',
#  '/boxscores/202102190PHI.html',
#  '/boxscores/202102200CHI.html',
#  '/boxscores/202102220HOU.html',
#  '/boxscores/202102240CHI.html',
#  '/boxscores/202102260CHI.html',
#  '/boxscores/202103010CHI.html',
#  '/boxscores/202103030NOP.html',
#  '/boxscores/202103110CHI.html',
#  '/boxscores/202103120CHI.html',
#  '/boxscores/202103140CHI.html',
#  '/boxscores/202103160CHI.html',
#  '/boxscores/202103170CHI.html',
#  '/boxscores/202103190DEN.html',
#  '/boxscores/202103210DET.html',
#  '/boxscores/202103220CHI.html',
#  '/boxscores/202103240CHI.html',
#  '/boxscores/202103270SAS.html',
#  '/boxscores/202103290GSW.html',
#  '/boxscores/202103310PHO.html',
#  '/boxscores/202104020UTA.html',
#  '/boxscores/202104040CHI.html',
#  '/boxscores/202104060IND.html',
#  '/boxscores/202104080TOR.html',
#  '/boxscores/202104090ATL.html',
#  '/boxscores/202104110MIN.html',
#  '/boxscores/202104120MEM.html',
#  '/boxscores/202104140CHI.html',
#  '/boxscores/202104160CHI.html',
#  '/boxscores/202104170CHI.html',
#  '/boxscores/202104190BOS.html',
#  '/boxscores/202104210CLE.html',
#  '/boxscores/202104220CHI.html',
#  '/boxscores/202104240MIA.html',
#  '/boxscores/202104260MIA.html',
#  '/boxscores/202104280NYK.html',
#  '/boxscores/202104300CHI.html',
#  '/boxscores/202105010ATL.html',
#  '/boxscores/202105030CHI.html',
#  '/boxscores/202105060CHO.html',
#  '/boxscores/202105070CHI.html',
#  '/boxscores/202105090DET.html',
#  '/boxscores/202105110CHI.html',
#  '/boxscores/202105130CHI.html',
#  '/boxscores/202105150BRK.html',
#  '/boxscores/202105160CHI.html']

# %%
first_half_path = "https://www.basketball-reference.com"

# %%
#Create entire link to each boxscore
box_score_urls = [] 
for i in box_scores:
    i = first_half_path+i
    box_score_urls.append(i)

# %%
box_score_urls
# Out:
# ['https://www.basketball-reference.com/boxscores/202105160CHI.html',
#  'https://www.basketball-reference.com/boxscores/202012230CHI.html',
#  'https://www.basketball-reference.com/boxscores/202012260CHI.html',
#  'https://www.basketball-reference.com/boxscores/202012270CHI.html',
#  'https://www.basketball-reference.com/boxscores/202012290WAS.html',
#  'https://www.basketball-reference.com/boxscores/202012310WAS.html',
#  'https://www.basketball-reference.com/boxscores/202101010MIL.html',
#  'https://www.basketball-reference.com/boxscores/202101030CHI.html',
#  'https://www.basketball-reference.com/boxscores/202101050POR.html',
#  'https://www.basketball-reference.com/boxscores/202101060SAC.html',
#  'https://www.basketball-reference.com/boxscores/202101080LAL.html',
#  'https://www.basketball-reference.com/boxscores/202101100LAC.html',
#  'https://www.basketball-reference.com/boxscores/202101150OKC.html',
#  'https://www.basketball-reference.com/boxscores/202101170DAL.html',
#  'https://www.basketball-reference.com/boxscores/202101180CHI.html',
#  'https://www.basketball-reference.com/boxscores/202101220CHO.html',
#  'https://www.basketball-reference.com/boxscores/202101230CHI.html',
#  'https://www.basketball-reference.com/boxscores/202101250CHI.html',
#  'https://www.basketball-reference.com/boxscores/202101300CHI.html',
#  'https://www.basketball-reference.com/boxscores/202102010CHI.html',
#  'https://www.basketball-reference.com/boxscores/202102030CHI.html',
#  'https://www.basketball-reference.com/boxscores/202102050ORL.html',
#  'https://www.basketball-reference.com/boxscores/202102060ORL.html',
#  'https://www.basketball-reference.com/boxscores/202102080CHI.html',
#  'https://www.basketball-reference.com/boxscores/202102100CHI.html',
#  'https://www.basketball-reference.com/boxscores/202102120CHI.html',
#  'https://www.basketball-reference.com/boxscores/202102150IND.html',
#  'https://www.basketball-reference.com/boxscores/202102170CHI.html',
#  'https://www.basketball-reference.com/boxscores/202102190PHI.html',
#  'https://www.basketball-reference.com/boxscores/202102200CHI.html',
#  'https://www.basketball-reference.com/boxscores/202102220HOU.html',
#  'https://www.basketball-reference.com/boxscores/202102240CHI.html',
#  'https://www.basketball-reference.com/boxscores/202102260CHI.html',
#  'https://www.basketball-reference.com/boxscores/202103010CHI.html',
#  'https://www.basketball-reference.com/boxscores/202103030NOP.html',
#  'https://www.basketball-reference.com/boxscores/202103110CHI.html',
#  'https://www.basketball-reference.com/boxscores/202103120CHI.html',
#  'https://www.basketball-reference.com/boxscores/202103140CHI.html',
#  'https://www.basketball-reference.com/boxscores/202103160CHI.html',
#  'https://www.basketball-reference.com/boxscores/202103170CHI.html',
#  'https://www.basketball-reference.com/boxscores/202103190DEN.html',
#  'https://www.basketball-reference.com/boxscores/202103210DET.html',
#  'https://www.basketball-reference.com/boxscores/202103220CHI.html',
#  'https://www.basketball-reference.com/boxscores/202103240CHI.html',
#  'https://www.basketball-reference.com/boxscores/202103270SAS.html',
#  'https://www.basketball-reference.com/boxscores/202103290GSW.html',
#  'https://www.basketball-reference.com/boxscores/202103310PHO.html',
#  'https://www.basketball-reference.com/boxscores/202104020UTA.html',
#  'https://www.basketball-reference.com/boxscores/202104040CHI.html',
#  'https://www.basketball-reference.com/boxscores/202104060IND.html',
#  'https://www.basketball-reference.com/boxscores/202104080TOR.html',
#  'https://www.basketball-reference.com/boxscores/202104090ATL.html',
#  'https://www.basketball-reference.com/boxscores/202104110MIN.html',
#  'https://www.basketball-reference.com/boxscores/202104120MEM.html',
#  'https://www.basketball-reference.com/boxscores/202104140CHI.html',
#  'https://www.basketball-reference.com/boxscores/202104160CHI.html',
#  'https://www.basketball-reference.com/boxscores/202104170CHI.html',
#  'https://www.basketball-reference.com/boxscores/202104190BOS.html',
#  'https://www.basketball-reference.com/boxscores/202104210CLE.html',
#  'https://www.basketball-reference.com/boxscores/202104220CHI.html',
#  'https://www.basketball-reference.com/boxscores/202104240MIA.html',
#  'https://www.basketball-reference.com/boxscores/202104260MIA.html',
#  'https://www.basketball-reference.com/boxscores/202104280NYK.html',
#  'https://www.basketball-reference.com/boxscores/202104300CHI.html',
#  'https://www.basketball-reference.com/boxscores/202105010ATL.html',
#  'https://www.basketball-reference.com/boxscores/202105030CHI.html',
#  'https://www.basketball-reference.com/boxscores/202105060CHO.html',
#  'https://www.basketball-reference.com/boxscores/202105070CHI.html',
#  'https://www.basketball-reference.com/boxscores/202105090DET.html',
#  'https://www.basketball-reference.com/boxscores/202105110CHI.html',
#  'https://www.basketball-reference.com/boxscores/202105130CHI.html',
#  'https://www.basketball-reference.com/boxscores/202105150BRK.html',
#  'https://www.basketball-reference.com/boxscores/202105160CHI.html']

# %%
cols = ["Players", "MP", "FG","FGA","FG%","3PA","3P","3P%","FT","FTA","FT%","ORB","DRB",
        "TRB","AST","STL","BLK","TOV","PF","PTS","+/-","Chicago Score", "Opponent Score"]

box_score_frames_list = [] #fill up list with box score dataframes

for link in box_score_urls:
    req = requests.get(link)
    box_score_data = req.text
    box_score_soup = BeautifulSoup(box_score_data,'html.parser')
    chi_box_score_table = box_score_soup.find_all('table', id="box-CHI-game-basic") #Find all tables with an id of the box score
    table_rows= chi_box_score_table[0].find_all('tr')
    table_df = []
    
    for line in table_rows:
        scores = box_score_soup.find_all('div',{'class':'score'}) #Find Scores
        chi_score = scores[0]
        opp_score = scores[1]
        
        td = line.find_all('td')
        #site HTML has the players name under an <a tag...
        a = line.find_all('a') #Find all a tags
        a = str(a)
        a = a.replace(a[0:37],"<td class=\"right\" data-stat=\"player\">") #This will convert the a tag into looking like
                                                                            #an td tag
        a = a.replace("</a>","</td>") #Adjust the end tag to be a td end tag
        a = a.replace("]","")
        if len(td) > 0:
            a = BeautifulSoup(a,'html.parser')
            td.insert(0,a)
            td.insert(21,chi_score) #insert chicago's score as the last column of the dataframe
            td.insert(21,opp_score) #insert opp_score as the last column of the dataframe
       
        row = [line.text for line in td]
        if len(row) > 0: #Avois any rows that are empty
            table_df.append(row)
    temp_df = pd.DataFrame(table_df, columns=cols)
    box_score_frames_list.append(temp_df)

# %%
box_scores_df = pd.concat(box_score_frames_list)

# %%
box_scores_df.head(20) #This is a complete dataframe of game-by-game box scores of the Chicago Bulls 2020-2021 season
                        #still needs some cleaning though.
# Out:
#               Players            MP   FG  FGA   FG%   3PA    3P    3P%    FT  \
# 0          Coby White         31:16    6   13  .462     4     9   .444     3
# 1    Patrick Williams         29:37    4    8  .500     0     1   .000     3
# 2      Garrett Temple         28:38    3    5  .600     1     2   .500     0
# 3      Thaddeus Young         25:33    8   15  .533     0     1   .000     4
# 4     Lauri Markkanen         24:47    6   11  .545     2     4   .500     3
# 5       Javonte Green         23:14    3    5  .600     0     1   .000     0
# 6        Devon Dotson         21:25    5   10  .500     1     5   .200     0
# 7    Denzel Valentine         20:49    3    9  .333     2     4   .500     0
# 8   Cristiano Felício         17:57    2    5  .400     0     1   .000     1
# 9    Ryan Arcidiacono         16:44    5    6  .833     4     4  1.000     0
# 10    Al-Farouq Aminu  Did Not Play  112  118  None  None  None   None  None
# 11        Adam Mokoka  Did Not Play  112  118  None  None  None   None  None
# 12                              240   45   87  .517    14    32   .438    14
# 0    Patrick Williams         33:02    5   11  .455     1     3   .333     5
# 1          Coby White         30:28    2   11  .182     1     7   .143     4
# 2     Lauri Markkanen         30:12    6    9  .667     4     6   .667     5
# 3      Wendell Carter         25:46    2    5  .400     0     2   .000     2
# 4         Zach LaVine         25:18    9   19  .474     1     8   .125     3
# 5         Otto Porter         23:22    5   10  .500     0     2   .000     4
# 6    Ryan Arcidiacono         19:35    2    6  .333     1     4   .250     0
#
#      FTA    FT%   ORB   DRB   TRB   AST   STL   BLK   TOV    PF   PTS   +/-  \
# 0      4   .750     0     5     5     5     1     1     4     1    19    -9
# 1      3  1.000     3     4     7     1     1     2     3     2    11    -2
# 2      0            1     2     3     3     0     0     2     1     7    -7
# 3      6   .667     1     6     7     3     0     3     4     2    20    +5
# 4      4   .750     0     5     5     1     0     0     2     1    17   -11
# 5      0            0     2     2     1     4     1     0     3     6   +12
# 6      0            0     2     2     4     1     0     0     2    11   +13
# 7      0            0     2     2     3     0     1     0     3     8    +9
# 8      2   .500     3     5     8     0     1     0     0     2     5    +5
# 9      0            0     4     4     2     0     0     1     3    14   +15
# 10  None   None  None  None  None  None  None  None  None  None  None  None
# 11  None   None  None  None  None  None  None  None  None  None  None  None
# 12    19   .737     8    37    45    23     8     8    16    20   118
# 0      6   .833     0     4     4     1     1     1     0     2    16   -23
# 1      4  1.000     0     2     2     7     2     0     3     2     9   -13
# 2      5  1.000     1     6     7     4     2     0     2     1    21   -34
# 3      2  1.000     1     5     6     2     0     0     3     3     6   -13
# 4      3  1.000     1     1     2     1     1     0     5     5    22   -26
# 5      4  1.000     3     2     5     1     2     0     1     2    14    -9
# 6      0            0     3     3     2     1     0     0     2     5    +6
#
#    Chicago Score Opponent Score
# 0            118            112
# 1            118            112
# 2            118            112
# 3            118            112
# 4            118            112
# 5            118            112
# 6            118            112
# 7            118            112
# 8            118            112
# 9            118            112
# 10          None           None
# 11          None           None
# 12           118            112
# 0            104            124
# 1            104            124
# 2            104            124
# 3            104            124
# 4            104            124
# 5            104            124
# 6            104            124

# %%
box_score_totals_df = box_scores_df.loc[box_scores_df['Players']==''] #Select totals rows

# %%
#Some scores are being pulled incorrectly. Next few lines fix that.
#Where ever PTS = Opponent score, we have an issue. PTS is the total points the bulls scored.
#So, if they are the same, then it would appear the scraper switched the opponent score and bulls score
box_score_totals_df["Opponent Score Fix"] = np.where(box_score_totals_df['PTS'] == box_score_totals_df["Opponent Score"], 
             box_score_totals_df["Chicago Score"],box_score_totals_df["Opponent Score"]) #Flip Chicago score and Opp score
# Out:
# C:\Users\joelf\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
box_score_totals_df=box_score_totals_df.iloc[1:] #First row is a duplicate of last game vs MIL

# %%
box_score_totals_df = box_score_totals_df.drop(columns=["Players","Chicago Score","Opponent Score","+/-"])

# %%
box_score_totals_df = box_score_totals_df.rename(columns={"Opponent Score Fix":"Opponent Score","PTS":"Chicago Score"})

# %%
box_score_totals_df.head()
# Out:
#      MP  FG FGA   FG% 3PA  3P   3P%  FT FTA   FT% ORB DRB TRB AST STL BLK TOV  \
# 15  240  36  87  .414   8  35  .229  24  28  .857   8  29  37  20  10   3  15
# 15  240  34  91  .374  16  39  .410  22  25  .880  13  28  41  23   7   7  20
# 15  240  44  86  .512  17  41  .415  23  31  .742   7  47  54  27   4   6  24
# 15  240  38  87  .437  15  36  .417  24  32  .750   5  32  37  26   7   1  14
# 13  240  50  92  .543  14  36  .389  19  25  .760   9  35  44  34   9   3  15
#
#     PF Chicago Score Opponent Score
# 15  22           104            124
# 15  16           106            125
# 15  21           128            129
# 15  23           115            107
# 13  27           133            130

# %%
dtype_change = box_score_totals_df[['Chicago Score','Opponent Score']].astype(int) #Change scoring columns to int types

# %%
box_score_totals_df["Formatted Chicago Score"] = dtype_change['Chicago Score']

# %%
box_score_totals_df["Formatted Opponent Score"] = dtype_change['Opponent Score']

# %%
#Create column to demonstrate if the bulls won or not.
box_score_totals_df["W/L"] = np.where(box_score_totals_df["Formatted Chicago Score"] > box_score_totals_df["Formatted Opponent Score"],"1","0")

# %%
box_score_totals_df.head()
# Out:
#      MP  FG FGA   FG% 3PA  3P   3P%  FT FTA   FT% ORB DRB TRB AST STL BLK TOV  \
# 15  240  36  87  .414   8  35  .229  24  28  .857   8  29  37  20  10   3  15
# 15  240  34  91  .374  16  39  .410  22  25  .880  13  28  41  23   7   7  20
# 15  240  44  86  .512  17  41  .415  23  31  .742   7  47  54  27   4   6  24
# 15  240  38  87  .437  15  36  .417  24  32  .750   5  32  37  26   7   1  14
# 13  240  50  92  .543  14  36  .389  19  25  .760   9  35  44  34   9   3  15
#
#     PF Chicago Score Opponent Score  Formatted Chicago Score  \
# 15  22           104            124                      104
# 15  16           106            125                      106
# 15  21           128            129                      128
# 15  23           115            107                      115
# 13  27           133            130                      133
#
#     Formatted Opponent Score W/L
# 15                       124   0
# 15                       125   0
# 15                       129   0
# 15                       107   1
# 13                       130   1

# %%
box_score_totals_df = box_score_totals_df.drop(columns=["Chicago Score","Opponent Score"])

# %%
box_score_totals_df = box_score_totals_df.rename(columns={"Formatted Chicago Score": "Chicago Score","Formatted Opponent Score":"Opponent Score"})

# %%
box_score_totals_df.head()
# Out:
#      MP  FG FGA   FG% 3PA  3P   3P%  FT FTA   FT% ORB DRB TRB AST STL BLK TOV  \
# 15  240  36  87  .414   8  35  .229  24  28  .857   8  29  37  20  10   3  15
# 15  240  34  91  .374  16  39  .410  22  25  .880  13  28  41  23   7   7  20
# 15  240  44  86  .512  17  41  .415  23  31  .742   7  47  54  27   4   6  24
# 15  240  38  87  .437  15  36  .417  24  32  .750   5  32  37  26   7   1  14
# 13  240  50  92  .543  14  36  .389  19  25  .760   9  35  44  34   9   3  15
#
#     PF  Chicago Score  Opponent Score W/L
# 15  22            104             124   0
# 15  16            106             125   0
# 15  21            128             129   0
# 15  23            115             107   1
# 13  27            133             130   1

# %%
box_score_totals_df["W/L"].value_counts() #Should say L: 41, W: 31
# Out:
# 0    41
# 1    31
# Name: W/L, dtype: int64

# %%
box_score_totals_df.to_csv('chicago_bulls_2019_2020.csv',index=False)

# %% [markdown]
# ### Using this refined dataset, we will utilize machine learning techniques to project if the bulls will win or lose based on a game's statistics/boxscore
